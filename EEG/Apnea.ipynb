# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import matplotlib.pyplot as plt
df_1 = pd.read_csv('C:/Users/santi/Downloads/apnea.txt', delim_whitespace=True)

# %%
df_1
# Out:
#       0.0937  -0.0484  0.2124
# 0     0.8481  -0.3678  2.1813
# 1     1.3824  -0.1148  4.2361
# 2     1.6594   1.4322  5.3500
# 3     2.5271   4.2851  5.5493
# 4     4.5173   7.7329  5.2305
# ..       ...      ...     ...
# 994   0.3356   4.0571  1.8425
# 995   4.8523   6.6573  3.1591
# 996  10.1427  10.5026  5.5146
# 997  12.0962  12.0567  8.0259
# 998   9.0595   9.1914  8.4682
#
# [999 rows x 3 columns]

# %%
# Crear la figura y los ejes
plt.figure(figsize=(10, 6))

# Graficar los tres canales usando .iloc para referirse a las columnas por su posición
plt.plot(df_1.index, df_1.iloc[:, 0], label='Canal 1')  # Primera columna: Canal 1
plt.plot(df_1.index, df_1.iloc[:, 1], label='Canal 2')  # Segunda columna: Canal 2
plt.plot(df_1.index, df_1.iloc[:, 2], label='Canal 3')  # Tercera columna: Canal 3

# Etiquetas y título
plt.title('Gráfica de Apnea: Voltaje vs Tiempo')
plt.xlabel('Tiempo (s)')
plt.ylabel('Voltaje (V)')

# Mostrar la leyenda
plt.legend()

# Mostrar la gráfica
plt.grid(True)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Derivada de cada canal
derivada_canal_1 = np.gradient(df_1.iloc[:, 0])
derivada_canal_2 = np.gradient(df_1.iloc[:, 1])
derivada_canal_3 = np.gradient(df_1.iloc[:, 2])

plt.figure(figsize=(10, 6))

# Graficar las derivadas
plt.plot(df_1.index, derivada_canal_1, label='Derivada Canal 1')
plt.plot(df_1.index, derivada_canal_2, label='Derivada Canal 2')
plt.plot(df_1.index, derivada_canal_3, label='Derivada Canal 3')

plt.title('Derivada de la Señal: Voltaje vs Tiempo')
plt.xlabel('Tiempo (s)')
plt.ylabel('Derivada del Voltaje (V/s)')

# Mostrar la leyenda
plt.legend()

# Mostrar la gráfica
plt.grid(True)
plt.show()

# %%
# Derivada de cada canal
derivada_canal_1 = np.gradient(df_1.iloc[:, 0])
derivada_canal_2 = np.gradient(df_1.iloc[:, 1])
derivada_canal_3 = np.gradient(df_1.iloc[:, 2])

# Crear la figura y los ejes
plt.figure(figsize=(10, 6))

# Graficar las derivadas usando la posición (índice) en el eje X
plt.plot(df_1.iloc[:,0], derivada_canal_1, label='Derivada Canal 1')
plt.plot(df_1.iloc[:,1], derivada_canal_2, label='Derivada Canal 2')
plt.plot(df_1.iloc[:,2], derivada_canal_3, label='Derivada Canal 3')


# Etiquetas y título
plt.title('Derivada de la Señal vs Posición')
plt.xlabel('Posición')
plt.ylabel('Derivada del Voltaje')

# Mostrar la leyenda
plt.legend()

# Mostrar la gráfica
plt.grid(True)
plt.show()

# %%
correlacion_1_2 = df_1.iloc[:, 0].corr(df_1.iloc[:, 1])
correlacion_2_3 = df_1.iloc[:, 1].corr(df_1.iloc[:, 2])


print(correlacion_1_2)
print(correlacion_2_3)
# Out:
# 0.8402716968172919
# 0.34501402954466653
